# %%
# %load_ext sql

# %%
# !pip install SQLAlchemy==1.4.49

# %%
# !pip install pymysql

# %%
import pymysql
import pandas as pd

# Create connection
conn = pymysql.connect(
    host='localhost',
    user='root',
    password='Diagnostic_56',
    database='united_nations'
)

# Example query
query = "SELECT Sub_region, Country_name, Land_area FROM united_nations.Access_to_Basic_Services WHERE Time_period = 2020 AND Land_area IS NOT NULL"
df = pd.read_sql(query, conn)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20920\1183719399.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#          Sub_region  Country_name  Land_area
# 0      Central Asia    Kazakhstan  2699700.0
# 1      Central Asia    Tajikistan   138790.0
# 2      Central Asia  Turkmenistan   469930.0
# 3      Central Asia    Uzbekistan   440650.0
# 4     Southern Asia   Afghanistan   652230.0
# ..              ...           ...        ...
# 125  Western Africa         Niger  1266700.0
# 126  Western Africa       Nigeria   910770.0
# 127  Western Africa       Senegal   192530.0
# 128  Western Africa  Sierra Leone    72180.0
# 129  Western Africa          Togo    54390.0
#
# [130 rows x 3 columns]

# %%
import pymysql
import pandas as pd

# Create connection
conn = pymysql.connect(
    host='localhost',
    user='root',
    password='Diagnostic_56',
    database='united_nations'
)

# Query
query = ""
df = pd.read_sql(query, conn)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20920\50122202.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3_1\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# File ~\anaconda3_1\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~\anaconda3_1\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# ...

# %%
#Task 1: Select the data required for the analysis

import pymysql
import pandas as pd

# Create connection
conn = pymysql.connect(
    host='localhost',
    user='root',
    password='Diagnostic_56',
    database='united_nations'
)

# Query
query = "SELECT Sub_region, Country_name, Land_area, ROUND(Land_area/SUM(Land_area) OVER (PARTITION BY sub_region)*100,4) AS pct_sub_region_land_area FROM united_nations.access_to_basic_services WHERE time_period = 2020 AND Land_area IS NOT NULL;"
df = pd.read_sql(query, conn)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20920\3155911473.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#                     Sub_region         Country_name  Land_area  \
# 0    Australia and New Zealand            Australia  7692020.0
# 1    Australia and New Zealand          New Zealand   263310.0
# 2                    Caribbean              Jamaica    10830.0
# 3                    Caribbean  Trinidad and Tobago     5130.0
# 4                    Caribbean             Barbados      430.0
# ..                         ...                  ...        ...
# 125               Western Asia                Qatar    11490.0
# 126               Western Asia                 Oman   309500.0
# 127               Western Asia              Lebanon    10230.0
# ...

# %%
#Task 2: Calculate the land area covered as a percentage of the country's subregion
import pymysql
import pandas as pd

# Create connection
conn = pymysql.connect(
    host='localhost',
    user='root',
    password='Diagnostic_56',
    database='united_nations'
)

# Query
query = "SELECT Sub_region, Country_name, Land_area, ROUND(Land_area/SUM(Land_area) OVER (PARTITION BY sub_region)*100,4) AS pct_sub_region_land_area FROM united_nations.access_to_basic_services WHERE time_period = 2020 AND Land_area IS NOT NULL;"
df = pd.read_sql(query, conn)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20920\1227264897.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#                     Sub_region         Country_name  Land_area  \
# 0    Australia and New Zealand            Australia  7692020.0
# 1    Australia and New Zealand          New Zealand   263310.0
# 2                    Caribbean              Jamaica    10830.0
# 3                    Caribbean  Trinidad and Tobago     5130.0
# 4                    Caribbean             Barbados      430.0
# ..                         ...                  ...        ...
# 125               Western Asia                Qatar    11490.0
# 126               Western Asia                 Oman   309500.0
# 127               Western Asia              Lebanon    10230.0
# ...

# %%
#Task 3: Calculate The running population average for each country's subregion

import pymysql
import pandas as pd

# Create connection
conn = pymysql.connect(
    host='localhost',
    user='root',
    password='Diagnostic_56',
    database='united_nations'
)

# Query
query = "SELECT Sub_region,Country_name, Time_period, Pct_managed_drinking_water_services, Pct_managed_sanitation_services, Est_gdp_in_billions, Est_population_in_millions, ROUND(AVG(Est_population_in_millions) OVER (PARTITION BY Sub_region ORDER BY Time_period),4) AS Running_average_population FROM united_nations.access_to_basic_services WHERE Est_gdp_in_billions IS NOT NULL;"
df = pd.read_sql(query, conn)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20920\1712983656.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#                     Sub_region Country_name  Time_period  \
# 0    Australia and New Zealand    Australia         2015
# 1    Australia and New Zealand  New Zealand         2015
# 2    Australia and New Zealand  New Zealand         2016
# 3    Australia and New Zealand    Australia         2016
# 4    Australia and New Zealand    Australia         2017
# ..                         ...          ...          ...
# 795               Western Asia       Jordan         2020
# 796               Western Asia      Georgia         2020
# 797               Western Asia       Israel         2020
# 798               Western Asia       Cyprus         2020
# ...
